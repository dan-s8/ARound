# %%
import pandas as pd
import json
import time
import numpy as np
from IPython.display import display
import ipywidgets as widgets

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error

# %%
# youtube
from googleapiclient.discovery import build
API_KEY = 'AIzaSyDfhiUHhz21lJHxJxsiy19D5KL5bYGqtL8'
# Initialize the YouTube Data API client
api_service_name = "youtube"
api_version = "v3"
youtube = build(api_service_name, api_version, developerKey=API_KEY)

# %%
# spotify
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials 
client_id = "125fcec321e048db972933f9f364d74e"
client_secret = "615237e26e0c4d22a13889fd7b91a46a"
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
## Step 1: Import Pollstar Data

# %%
# Load data
data = pd.read_csv('a-round-pollstar.csv')
data.head(3)
# Out:
#    Unnamed: 0  Event Date  # Shows Headliner Support             Venue  \
# 0           1  2023-11-04        1    xikers     NaN  Warfield Theatre
# 1           2  2023-11-03        1  EVERGLOW     NaN     Kings Theatre
# 2           3  2023-11-01        1    Xikers     NaN   Orpheum Theatre
#
#             City       State        Country                          Market  \
# 0  San Francisco  California  United States  San Francisco-Oakland-San Jose
# 1       Brooklyn    New York  United States                        New York
# 2    Los Angeles  California  United States                     Los Angeles
#
#    ...             Promoter      Genre Avg. Tickets Sold Avg. Gross USD  \
# 0  ...  Sean Healy Presents  Asian Pop            1261.0      152175.02
# 1  ...  Sean Healy Presents  Asian Pop             941.0      100970.00
# 2  ...  Sean Healy Presents  Asian Pop            1812.0      209839.65
#
#    Avg. Event Capacity  Avg. Capacity Sold  Ticket Price Min  \
# 0               1780.0                71.0              50.0
# 1               2312.0                41.0              60.0
# 2               1924.0                94.0              50.0
#
#    Ticket Price Max  Ticket Price Avg. USD  Unnamed: 21
# 0             175.0                 120.68          NaN
# 1             195.0                 107.30          NaN
# 2             175.0                 115.81          NaN
#
# [3 rows x 22 columns]

# %%
# Data preprocessing for pollstar data

# Check if 'Event Date' column contains valid dates
data['Event Date'] = pd.to_datetime(data['Event Date'], errors='coerce')

# Drop rows where 'Event Date' is null (indicating invalid date)
data = data.dropna(subset=['Event Date'])

# Reset index after dropping rows
data = data.reset_index(drop=True)

# %%
# extract month from Event Date to represent seasonality
data['Event Date'] = pd.to_datetime(data['Event Date'], format='%m/%d/%Y')
data['Month'] = data['Event Date'].dt.month

# %%
# Remove commas and convert to float
data['Avg. Gross USD'] = data['Avg. Gross USD'].astype(float)

# %%
# create a Location column using 'City', 'State','Country'
data['Location'] = data['City'] + '_' + data['State'] + '_' + data['Country']

# %%
## Step 2: Extract artist names

# %%
artist_names = data['Headliner'].unique()

# Print or use the unique values as needed
print((artist_names))
# Out:
# ['xikers' 'EVERGLOW' 'Xikers' 'The Rose' 'ENHYPEN'
#  '"Mcountdown In France"' 'tripleS' 'Stay-C' 'Radwimps'
#  'BABYMETAL, Metalocalypse: Dethklok' 'P1harmony' 'Loona' 'Twice'
#  'Jonathan Lee' 'SEVENTEEN' 'ATEEZ' 'TOMORROW X TOGETHER'
#  '"Lollapalooza Aftershows", The Rose' 'Suga' 'Rain' 'Enhypen' 'KARD'
#  'NCT Dream' 'BLACKPINK' 'Red Velvet' 'Nmixx' 'Mayday' 'JJ Lin' 'Sabaton'
#  'Baek Z Young' 'Stray Kids' 'CIX' 'NCT 127' 'Seventeen'
#  'DPR Live, DPR IAN, DPR Cream' 'ITZY' 'MUSTB' 'G I-DLE'
#  'Tomorrow X Together' 'Monsta X' 'The Boyz' 'BTS' 'BABYMETAL' 'Day6'
#  'Got7' 'Little Simz' 'Ateez' '"KCon", Mamamoo' 'Band Of Horses'
#  '"Billboard Music Awards"' 'Fei Yu Ching' 'Winner' 'Ssingssing'
#  'Jacky Cheung' 'Rene Liu' 'B.A.P.' 'Jane Zhang' 'Wanna One' 'Up10tion'
#  'Leehom Wang' 'Zhang Jun' 'Nine Percent' 'Chris Lee (Li Yuchun)'
#  'Yu-Ching Fei' 'Snh48' 'A-Mei' 'Kuang Program' 'FTIsland' 'Yu-Rong Yang'
#  'Lala Hsu' 'G-Dragon' 'Silence (Wang Su Long)' 'Bibi Zhou' 'Taeyang'
#  'Ronghao Li' 'Lion' 'Pu Shu' 'Tanya Chua' 'JJCC' 'Hebe Tien' 'Korn'
#  'Luo Tianyi' 'Kard' 'Joker Xue' '"Northside Festival", Pelada'
#  'Mua He Ruc Ro' 'Rica Matsumoto' 'Red Hot Chili Peppers' 'EXO' '7 Senses'
#  'A Little Fever (ATF)' 'B1A4' "Guns N' Roses" 'Akdong Musician'
#  'Momoiro Clover Z' 'CL' 'Bastille' 'Zhang Jie' 'Twins LOL' 'T-ara'
#  'Brilliance Yu' 'Sammi Cheng' 'Big Bang' 'Zhang Hang' 'Eir Aoi'
#  'Bigbang (Korea)' 'Yanzi Kepler' 'Lisa' 'TsuShiMaMiRe'
#  '"Asian Night", Mua Thu Cho Em' '2PM' 'Lee Juck' 'Mr.' 'Lady Gaga'
#  'C Allstar' 'Hebe Tien, Yoga Lin' 'RJD2' '"The Script Road"' 'Vixx'
#  'Swervedriver' '"KMVQ Triple Ho Show"' 'Tyme x Tujiko' '2NE1'
#  'FTIsland, CNBlue' 'Lee Horn' '2*Sweet' 'Inept' 'Set Your Goals' 'June'
#  'A Loss For Words' 'Lucky Boys Confusion' 'Chang Cheng-Yue'
#  'Chang Cheng-Yue, Free9' 'Box-O-Car' 'Danzig' 'Anthrax']

# %%
## Step 3: Pull and Merge Youtube Data

# %%
def get_channel_basic_info_name(channel_names):
    channel_info_list = []
    
    for channel_name in channel_names:
        try:
            # Search for channels with the specified name
            search_request = youtube.search().list(
                part='snippet',
                type='channel',
                q=channel_name
            )
            search_response = search_request.execute()

            # Check if there are any search results
            if 'items' in search_response and search_response['items']:
                # Select the most relevant channel from the search results
                top_result = search_response['items'][0]
                channel_id = top_result['id']['channelId']
                
                # Call the channels.list method to retrieve information about the channel
                request = youtube.channels().list(
                    part="snippet,statistics",
                    id=channel_id
                )
                response = request.execute()

                # Extract relevant information from the API response
                channel_info = response['items'][0]
                snippet = channel_info['snippet']
                statistics = channel_info['statistics']

                # Store the information in a dictionary
                channel_data = {
                    "yt name":channel_name,
                    "yt Channel ID": channel_id,
                    "yt Title": snippet['title'],
                    "yt Description": snippet['description'],
                    "yt Published At": snippet['publishedAt'],
                    "yt View Count": statistics.get('viewCount', 0),
                    "yt Subscriber Count": statistics.get('subscriberCount', 0),
                    "yt Video Count": statistics.get('videoCount', 0)
                }

                # Append channel information to the list
                channel_info_list.append(channel_data)
                # print(channel_data)
            else:
                print(f"No channel found with the name: {channel_name}")

        except Exception as e:
            print(f"Error occurred: {e}")
    # Create a DataFrame from the list of dictionaries
    channel_df = pd.DataFrame(channel_info_list)
    return channel_df

# %%
yt_channel_info_df = get_channel_basic_info_name(artist_names)
# yt_channel_info_df = get_channel_basic_info_name(['2NE1'])
print(yt_channel_info_df)
# Out:
# {'yt name': 'xikers', 'yt Channel ID': 'UCPtC0MXSW40Qq7RkhsCXjUQ', 'yt Title': 'xikers', 'yt Description': 'xikers(싸이커스) Official YouTube Channel\n', 'yt Published At': '2022-11-15T14:21:56.347452Z', 'yt View Count': '37578254', 'yt Subscriber Count': '375000', 'yt Video Count': '846'}
# {'yt name': 'EVERGLOW', 'yt Channel ID': 'UCg3scYhWcPmyfJcSkulJcow', 'yt Title': 'Everglow', 'yt Description': "Welcome to my channel! \nMy name is Marco, I'm from Italy and as you can see by a quick look, I focused all of my channel to the Kingdom Hearts video game saga.\nOn this channel I upload videos that I have filmed and edited myself. They're not just ORIGINAL videos but I also try and help with video guides and translations, all of them realized by me. Every video shows step-by-step the ways to beat the KH games.\n\nI also work on translations for the Japanese exclusive story updates of Kingdom Hearts Union x [Cross]. \nIt's a very hard work that you can't find anywhere else, since every dialogue has been translated and realized by me. These translations are fundamental to the understanding of Kingdom Hearts 3, a game that the whole community has been waiting for 12 years. \n\nDon't get fooled by the similar thumbnails! They're all part of a big project so each video is different and original!\n\n\nHopefully my channel is clear enough to let you find the content you need!", 'yt Published At': '2012-07-18T21:07:58Z', 'yt View Count': '28337056', 'yt Subscriber Count': '110000', 'yt Video Count': '554'}
# {'yt name': 'Xikers', 'yt Channel ID': 'UCPtC0MXSW40Qq7RkhsCXjUQ', 'yt Title': 'xikers', 'yt Description': 'xikers(싸이커스) Official YouTube Channel\n', 'yt Published At': '2022-11-15T14:21:56.347452Z', 'yt View Count': '37578254', 'yt Subscriber Count': '375000', 'yt Video Count': '846'}
# {'yt name': 'The Rose', 'yt Channel ID': 'UClcbcYLmTpDeuK1EFeqh5uA', 'yt Title': 'The Rose', 'yt Description': 'The Rose Official 🌹\n\nKorean Alt Pop Band\nDUAL OUT NOW\nInfo@transparentarts.com\nLinktr.ee/theroseofficial\n\n더로즈 공식 @official_ therose \n기타/보컬_우성 @iwoosung\n건반,기타/보컬_도준 @parclassic\n베이스_재형 @gud0011\n드럼_하준 @I_hajoon', 'yt Published At': '2016-12-16T07:48:04Z', 'yt View Count': '278125618', 'yt Subscriber Count': '1590000', 'yt Video Count': '210'}
# {'yt name': 'ENHYPEN', 'yt Channel ID': 'UCArLZtok93cO5R9RI4_Y5Jw', 'yt Title': 'ENHYPEN', 'yt Description': '#ENHYPEN Official Youtube\n#ENHYPEN 공식 유튜브', 'yt Published At': '2020-08-10T12:46:00.218737Z', 'yt View Count': '1786185504', 'yt Subscriber Count': '9360000', 'yt Video Count': '1206'}
# {'yt name': 'Sabaton', 'yt Channel ID': 'UCjQhd1APsd5NQhiVZV7GYzg', 'yt Title': 'Sabaton', 'yt Description': 'Sabaton are a five-piece metal band from Falun, Sweden. \n\nCombining soaring power riffs with distinctive deep vocals, their lyrics focus on the exploits of war, from ancient historical battles to modern acts of heroism. \n\nTheir electrifying live show – which features a full-sized and firing tank – has won numerous industry accolades, while two of their ten studio albums are certified platinum sellers. \n\nTheir most recent album, The War To End All Wars, reached #1 position in the charts in several countries including Germany, Sweden, Finland and Poland.\n\nThe band, who are signed to the worlds biggest metal label Nuclear Blast are doing over 100 shows every year all around the world.', 'yt Published At': '2006-02-06T09:16:49Z', 'yt View Count': '1523240078', 'yt Subscriber Count': '1890000', 'yt Video Count': '669'}
# {'yt name': 'Baek Z Young', 'yt Channel ID': 'UCIn1p2ZbhOo8fyZp1S60uGg', 'yt Title': '백지영 Baek Z Young', 'yt Description': "'백지영' 채널에 오신 것을 환영합니다!!🙌 \n\n쎈 언니일 것 같지만 이 언니 증말 아무것도 모르더라구영🤷\u200d♀️\n이 기회에 열심히 유튜버로 만들어보겠습니다❤\n\n다들 구독, 좋아요, 알림설정!! 꾹꾹 눌어주세요!!🙏\n\n비즈니스 문의 : realbaekzyoung@gmail.com\n", 'yt Published At': '2020-11-02T02:16:42.962628Z', 'yt View Count': '139605824', 'yt Subscriber Count': '238000', 'yt Video Count': '52'}
# {'yt name': 'Stray Kids', 'yt Channel ID': 'UC9rMiEjNaCSsebs31MRDCRA', 'yt Title': 'Stray Kids', 'yt Description': 'Stray Kids Official YouTube', 'yt Published At': '2017-05-12T03:28:10Z', 'yt View Count': '4625292848', 'yt Subscriber Count': '15800000', 'yt Video Count': '1015'}
# {'yt name': 'CIX', 'yt Channel ID': 'UCuaslC77K-NmCy8Xwk7x0hA', 'yt Title': 'CIX Official', 'yt Description': 'C9Entertainment CIX Official Youtube', 'yt Published At': '2019-01-08T10:04:21Z', 'yt View Count': '231851029', 'yt Subscriber Count': '1040000', 'yt Video Count': '647'}
# {'yt name': 'NCT 127', 'yt Channel ID': 'UCk2E0dbAyEJWnrN2bbQOcbg', 'yt Title': 'NCT 127', 'yt Description': '【Be There For Me - Winter Special Single】\n\nWelcome to NCT 127 Official YouTube Channel!', 'yt Published At': '2017-06-07T05:47:43Z', 'yt View Count': '1191537788', 'yt Subscriber Count': '5560000', 'yt Video Count': '727'}
# {'yt name': 'Seventeen', 'yt Channel ID': 'UCfkXDY7vwkcJ8ddFGz8KusA', 'yt Title': 'SEVENTEEN', 'yt Description': '#SEVENTEEN Official Youtube\n#세븐틴 공식 유튜브\n', 'yt Published At': '2012-11-16T08:20:35Z', 'yt View Count': '5232358835', 'yt Subscriber Count': '10800000', 'yt Video Count': '1894'}
# {'yt name': 'DPR Live, DPR IAN, DPR Cream', 'yt Channel ID': 'UCtG5oKSlksz-QmD_2uI4WBw', 'yt Title': 'Dream Perfect Regime', 'yt Description': 'Dream Perfect Regime (DPR) is an independent, multi-genre music and video group. We create, direct, and edit all types of visual work as well as curate artists stemming from a wide array of musical backgrounds and influences. Currently based in seoul, our primary focus is to engage viewers by producing a unique and dynamic experience of both visual and audio output \n\nDream Perfect Regime\n#DPR\n\n\nwww.dreamperfectregime.com', 'yt Published At': '2014-12-04T11:13:27Z', 'yt View Count': '552665085', 'yt Subscriber Count': '1410000', 'yt Video Count': '69'}
is a powerful singer and music producer in mainland China.\n\nSilence Wang graduated from Shenyang Conservatory of Music. Since his debut, he has published 10 albums, more than 200 original singles and many popular singles with high popularity. It is not only a singer with both popularity and strength, but also a well-known variety show blockbuster. He constantly shows his outstanding musical talent with his own changeable music style.\n', 'yt Published At': '2022-10-21T07:00:58.919698Z', 'yt View Count': '45211367', 'yt Subscriber Count': '32100', 'yt Video Count': '7'}
# {'yt name': 'Bibi Zhou', 'yt Channel ID': 'UCuQ1Xg05DTXtvSAHY891WFg', 'yt Title': '周筆暢官方專屬頻道Bibi Zhou Official Channel', 'yt Description': 'Welcome to the official channel of Bibi Zhou\n歡迎來到周筆暢官方專屬頻道 \n- https://bit.ly/2XaAgT3', 'yt Published At': '2013-12-06T10:31:52Z', 'yt View Count': '2337640', 'yt Subscriber Count': '9930', 'yt Video Count': '101'}
# {'yt name': 'Taeyang', 'yt Channel ID': 'UCDJnRpq0DnQhrwi1ruuQa7g', 'yt Title': 'TAEYANG', 'yt Description': 'TAEYANG Official YouTube Channel\n태양 공식 유튜브 채널입니다.', 'yt Published At': '2009-08-21T01:19:45Z', 'yt View Count': '319418760', 'yt Subscriber Count': '1830000', 'yt Video Count': '70'}
# {'yt name': 'Ronghao Li', 'yt Channel ID': 'UCbGkxRgcnFTNNh3FDJOoJHA', 'yt Title': "Ronghao Li's Official Channel 李榮浩官方專屬頻道", 'yt Description': '', 'yt Published At': '2014-11-28T10:32:41Z', 'yt View Count': '599777825', 'yt Subscriber Count': '344000', 'yt Video Count': '60'}
# {'yt name': 'Lion', 'yt Channel ID': 'UCjNea6tkE7f0WHR50iNPf5A', 'yt Title': 'Lion Family English', 'yt Description': 'Welcome to Lion family. \nChannel  engage children preschool kids with fun and educational content.\nHere you can watch adventures of Leo and his friends. They always look for something new. Their curiosity and creativeness causes funny adventures.\n\n', 'yt Published At': '2018-06-11T05:35:57Z', 'yt View Count': '719944658', 'yt Subscriber Count': '5760000', 'yt Video Count': '199'}
# {'yt name': 'Pu Shu', 'yt Channel ID': 'UCPisO2j3xd_R1sITJeRLNvA', 'yt Title': 'Pu Shu - Topic', 'yt Description': '', 'yt Published At': '2013-12-23T13:40:41Z', 'yt View Count': '27573341', 'yt Subscriber Count': '10000', 'yt Video Count': '62'}
# {'yt name': 'Tanya Chua', 'yt Channel ID': 'UC15Z8k3NNQ1LQnRqFwVcOkQ', 'yt Title': '蔡健雅 Tanya Chua', 'yt Description': '「用眼睛觀察生活，用音樂寫下感受。」坦誠和真實，我們聽到的就是Tanya最坦白的情感表達。\r\n\r\n她的名字，一直是音樂與愛情的關鍵字!\r\n她的歌曲，和她的人一樣，常常是一個人難過，一個人崩潰，然後再一個人痊癒，一個人重新生活，我們總是在她的歌曲裡接收到一種冷靜淡化後自我療傷的心情分享。\r\n\r\n我們總是習慣聽著她冷靜內斂的唱著所有動人的情歌，在她的旋律裡試圖投射，在她的歌聲裡尋求撫慰。\r\n\r\n她的聲音，有一種溫度，一種來自音樂感動人的溫度。', 'yt Published At': '2011-11-02T05:40:27Z', 'yt View Count': '133655434', 'yt Subscriber Count': '205000', 'yt Video Count': '103'}
# {'yt name': 'JJCC', 'yt Channel ID': 'UC4fGYf1YTRcFtSZyX1odeZw', 'yt Title': 'JJCC ShaShaNe 샤샤네', 'yt Description': 'Official JJCC / ShaShaNe 샤샤네', 'yt Published At': '2014-02-06T09:19:56Z', 'yt View Count': '6604800', 'yt Subscriber Count': '85500', 'yt Video Count': '114'}
# {'yt name': 'Hebe Tien', 'yt Channel ID': 'UCWASjJ7q476ZgxT9oWBSclg', 'yt Title': "Hebe Tien's Official Channel田馥甄官方專屬頻道", 'yt Description': '', 'yt Published At': '2018-12-10T12:20:00Z', 'yt View Count': '136171671', 'yt Subscriber Count': '164000', 'yt Video Count': '35'}
# {'yt name': 'Korn', 'yt Channel ID': 'UC6ly_u2ufiHGpYzC_28-8zw', 'yt Title': 'KoRn', 'yt Description': 'The official Korn YouTube channel.', 'yt Published At': '2006-08-29T23:37:19Z', 'yt View Count': '2569947598', 'yt Subscriber Count': '2900000', 'yt Video Count': '262'}
# {'yt name': 'Luo Tianyi', 'yt Channel ID': 'UCDUCCsxopoiZCtzdr81C6EQ', 'yt Title': '洛天依 - Luo Tianyi', 'yt Description': '', 'yt Published At': '2018-04-13T08:17:51Z', 'yt View Count': '3901882', 'yt Subscriber Count': '21600', 'yt Video Count': '8'}
# {'yt name': 'Kard', 'yt Channel ID': 'UC5OwlwvsVmf_lXHguB6OYFw', 'yt Title': 'KARD', 'yt Description': 'DSP Media KARD Official YouTube', 'yt Published At': '2016-11-10T06:48:44Z', 'yt View Count': '824835419', 'yt Subscriber Count': '3700000', 'yt Video Count': '536'}
# {'yt name': 'Joker Xue', 'yt Channel ID': 'UCeHAsNPoMw7xfNf0pH-CmJA', 'yt Title': '薛之 謙 - Topic', 'yt Description': '', 'yt Published At': '2016-09-07T04:19:38Z', 'yt View Count': '93582394', 'yt Subscriber Count': '42000', 'yt Video Count': '189'}
# No channel found with the name: "Northside Festival", Pelada
# {'yt name': 'Mua He Ruc Ro', 'yt Channel ID': 'UC0jDoh3tVXCaqJ6oTve8ebA', 'yt Title': 'FAPTV', 'yt Description': 'FAPTV được thành lập vào ngày 14/02/2014 bởi các thành viên: Đạo diễn Trần Đức Viễn, Rapper Thái Vũ (Black Bi), AT117 (Tài trợ về thiết bị) và người mẫu Ribi Sachi với niềm đam mê về nghệ thuật, mong muốn tạo ra điều khác biệt so với các nội dung video trên các mạng xã hội.\n\nNăm 2014 cũng là thời điểm mạng xã hội Youtube phát triển mạnh tại Việt Nam, các tiểu phẩm trên kênh FAPTV của nhóm ban đầu rất may mắn được cộng đồng mạng đón nhận, và thật sự tạo ra dấu ấn riêng khi Producer Trần Long, Vinh Râu cùng Huỳnh Phương tham gia trong sitcom Cơm Nguội. Nhóm hy vọng kênh FAPTV là nơi mọi người có thể truy cập để giải trí sau những giờ làm việc để giải toả những căng thẳng, mệt mỏi bằng những tình huống hài về các cuộc sống đời thường được kể theo cách riêng, dí dỏm và hài hước của FAPTV.\n\n', 'yt Published At': '2014-02-26T15:44:42Z', 'yt View Count': '5617814651', 'yt Subscriber Count': '13900000', 'yt Video Count': '1073'}
# {'yt name': 'Rica Matsumoto', 'yt Channel ID': 'UChqcf9JyfeDz_YS4ah-DJqA', 'yt Title': 'RICA MATSUMOTO', 'yt Description': '', 'yt Published At': '2015-02-20T10:08:47Z', 'yt View Count': '43', 'yt Subscriber Count': '1', 'yt Video Count': '1'}
# {'yt name': 'Red Hot Chili Peppers', 'yt Channel ID': 'UCrSorX845CEWXzU4Z7BojjA', 'yt Title': 'Red Hot Chili Peppers - Topic', 'yt Description': "We went in search of ourselves as the band that we have somehow always been. Just for the fun of it we jammed and learned some old songs. Before long we started the mysterious process of building new songs. A beautiful bit of chemistry meddling that had befriended us hundreds of times along the way. Once we found that slip stream of sound and vision, we just kept mining. With time turned into an elastic waist band of oversized underwear, we had no reason to stop writing and rocking. It felt like a dream. When all was said and done, our moody love for each other and the magic of music had gifted us with more songs than we knew what to do with. Well we figured it out. 2 double albums released back to back. The second of which is easily as meaningful as the first or should that be reversed. 'Return of the Dream Canteen' is everything we are and ever dreamed of being. It’s packed. Made with the blood of our hearts, yours truly, the Red Hot Chili Peppers.", 'yt Published At': '2013-05-16T14:09:58Z', 'yt View Count': '1516138450', 'yt Subscriber Count': '82100', 'yt Video Count': '1041'}
# {'yt name': 'EXO', 'yt Channel ID': 'UCEUX9tUYqTFfPQdAgVNsKTA', 'yt Title': 'EXO - Topic', 'yt Description': 'EXO, which is derived from ‘EXOPLANET’, a term denoting the planets outside the solar system, is a 9-member K-pop boy band. After making their anticipated debut in April 2012, EXO is now one of the “biggest K-POP boy band in the world”. Forbes noted their immense popularity on its “Korea Power Celebrity List”, which named them one of the Top 5 K-pop groups in 2014, 2017, and 2018. \n \nEXO’s first album XOXO (2013), containing the breakthrough hit “Growl” was a critical and commercial success. The album sold over 1 million copies, making them the first million-selling Korean artist in 12 years. Their subsequent releases also had strong sales, with all full-length albums each selling more than 1 million copies. EXO’s album Don’t Mess Up My Tempo (2018) is their highest charting-album on the US Billboard 200, debuting at number 23. \n\nSince their first headlining tour in 2014, EXO has performed over 100 concerts across four tours and participated in multiple joint tours, successfully wrapping up their 5th tour across Asia in 2019. In June 2021, EXO achieved their sixth ‘million seller’ status with their special album ‘DON’T FIGHT THE FEELING’, which not only topped various global charts, but marked No. 1 on iTunes music chart in 87 countries around the world, once again proving their title as the legendary K-POP group.', 'yt Published At': '2013-12-19T04:19:26Z', 'yt View Count': '723151231', 'yt Subscriber Count': '518000', 'yt Video Count': '748'}
# {'yt name': '7 Senses', 'yt Channel ID': 'UCmZBg-pfm7wlXwoWhL0bb-A', 'yt Title': '7th SENSE', 'yt Description': 'Dear traders, \n               Welcome to our Share Market "7th Sense" you tube channel. It ll build your trading knowledge in stock market so that you ll be a better trader in upcoming days and definitely book your profit. \n                If you fall in love with our channel kindly subscribe and click bell icon.\n                By investing your subscription you definitely book your profit.\n\nOur PDF !!\n "7th Sense" Trading channel has made all of its videos printable PDFs accessible through a PDF Lifetime subscription on our private telegram channel. To become a member, simply send a donation of Rs 3,000 to the following number: 8087339648. After making your donation, you\'ll be added to our private Telegram channel and granted lifetime access to all of 7th Sense\'s PDFs, which are updated every weekend. You can become an expert trader by reviewing each and every aspect of trading with the aid of these PDFs. Best wishes!!! \n\nThanks and Regards \n7th Sense channel \n whats app 8087339648\n', 'yt Published At': '2020-06-29T17:11:27.445797Z', 'yt View Count': '6189207', 'yt Subscriber Count': '205000', 'yt Video Count': '364'}
# {'yt name': 'A Little Fever (ATF)', 'yt Channel ID': 'UC6m9WMSuhfZaB7HV-ca1l8A', 'yt Title': '2Ajkell', 'yt Description': 'Everything 2A and CA Compliant Videos\n\nAll content is in line with state and federal laws and firearm safety is heavily practiced \n\n\n\n\n\n\n\n\n\nBusiness inquires: 2ajkell2a@gmail.com  \n\nWant to be in a unboxing video 😳🗿\n3206 N Dinuba Blvd Ste E Visalia, CA 93291 PO Box 111', 'yt Published At': '2014-12-26T12:53:28Z', 'yt View Count': '136769578', 'yt Subscriber Count': '318000', 'yt Video Count': '244'}
# {'yt name': 'B1A4', 'yt Channel ID': 'UCDBLl8TPgGzAzUGaqbpwAZA', 'yt Title': 'B1A4 OFFICIAL +', 'yt Description': 'B1A4 Official YouTube Channel', 'yt Published At': '2011-04-12T07:22:21Z', 'yt View Count': '243280162', 'yt Subscriber Count': '732000', 'yt Video Count': '451'}
# {'yt name': "Guns N' Roses", 'yt Channel ID': 'UCJN4c_lZorb_0eyIP_tSS3A', 'yt Title': 'GunsNRosesVEVO', 'yt Description': "Guns N' Roses on Vevo - Official Music Videos, Live Performances, Interviews and more...", 'yt Published At': '2009-05-12T05:28:04Z', 'yt View Count': '7819502675', 'yt Subscriber Count': '4570000', 'yt Video Count': '114'}
# {'yt name': 'Akdong Musician', 'yt Channel ID': 'UCIcXK1CI8URMIqNO_1cehiQ', 'yt Title': 'AKMU', 'yt Description': 'AKMU Official YouTube Channel\nAKMU 공식 유튜브 채널입니다.\n\nLEE CHANHYUK, LEE SUHYUN\n이찬혁, 이수현', 'yt Published At': '2014-03-13T09:02:56Z', 'yt View Count': '1386886630', 'yt Subscriber Count': '3240000', 'yt Video Count': '258'}
# {'yt name': 'Momoiro Clover Z', 'yt Channel ID': 'UC6YNWTm6zuMFsjqd0PO3G-Q', 'yt Title': 'Momoiro Clover Z Channel', 'yt Description': 'ももいろクローバーZ のオフィシャルYouTubeチャンネルです！\nThis is Momoiro Clover Z Official YouTube channel!\n\n7th ALBUMアルバム『イドラ』\n発売日：2024年5月8日（水）\n特設サイト\nURL：https://mcz-release.com/sound/idola/\n', 'yt Published At': '2014-04-08T08:03:55Z', 'yt View Count': '300050705', 'yt Subscriber Count': '627000', 'yt Video Count': '833'}
# {'yt name': 'CL', 'yt Channel ID': 'UCuX8lXIexG8dRXFx54CVm2Q', 'yt Title': 'CL Official Channel', 'yt Description': '+CL+\n', 'yt Published At': '2019-11-21T01:13:35.854589Z', 'yt View Count': '308201781', 'yt Subscriber Count': '2080000', 'yt Video Count': '72'}
key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# {'yt name': 'Bigbang (Korea)', 'yt Channel ID': 'UCn5Fol5NEcyotSwqrxsedtA', 'yt Title': 'Bigbear Korea channel', 'yt Description': 'ทางช่องเป็นเพียงสื่อกลางในการนำเสนอแนวทางตัวเลขสำหรับซื้อสลากกินแบ่งรัฐบาลที่ถูกกฎหมายเท่านั้น\n\nติดต่องานโฆษณา ลิขสิทธิ์ละเมิด อื่นๆ \nไลน์ไอดี basbasbellbell2 \nเพจเฟสบุ๊ค Bigbear Korea Channel ช่องหวย\nเฟสบุ๊คส่วนตัวแอดมิน (สำหรับติดต่อเรื่องด่วนเท่านั้น) คิม คายุน', 'yt Published At': '2016-05-20T11:38:40Z', 'yt View Count': '6403033', 'yt Subscriber Count': '269000', 'yt Video Count': '333'}
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Yanzi+Kepler&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/channels?part=snippet%2Cstatistics&id=UCqEfdEvLG5oQWNYlDQrGlKw&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=TsuShiMaMiRe&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=%22Asian+Night%22%2C+Mua+Thu+Cho+Em&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=2PM&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Lee+Juck&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Mr.&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Lady+Gaga&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=C+Allstar&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Hebe+Tien%2C+Yoga+Lin&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=RJD2&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=%22The+Script+Road%22&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Vixx&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Swervedriver&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=%22KMVQ+Triple+Ho+Show%22&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Tyme+x+Tujiko&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=2NE1&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=FTIsland%2C+CNBlue&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/channels?part=snippet%2Cstatistics&id=UCsPtPer9uD6zxGiWTk95-9Q&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=2%2ASweet&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Inept&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Set+Your+Goals&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=June&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=A+Loss+For+Words&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Lucky+Boys+Confusion&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Chang+Cheng-Yue&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Chang+Cheng-Yue%2C+Free9&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Box-O-Car&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Danzig&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# Error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&type=channel&q=Anthrax&key=AIzaSyBwuVXHMSMJB5XPoGcbeRuL8rBpKf5Cp80&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
#              yt name             yt Channel ID               yt Title  \
# 0             xikers  UCPtC0MXSW40Qq7RkhsCXjUQ                 xikers
# 1           EVERGLOW  UCg3scYhWcPmyfJcSkulJcow               Everglow
# 2             Xikers  UCPtC0MXSW40Qq7RkhsCXjUQ                 xikers
# 3           The Rose  UClcbcYLmTpDeuK1EFeqh5uA               The Rose
# 4            ENHYPEN  UCArLZtok93cO5R9RI4_Y5Jw                ENHYPEN
# ..               ...                       ...                    ...
# 97         Twins LOL  UC_wU67SRIz_AeeXozw6AJmw             AlphaTwins
# 98             T-ara  UCQXSTjAoqNh5HK5Ae6iwwjA            Tara's body
# 99     Brilliance Yu  UCU9TBOdDuL_j_J4WbwTvXTw                  Baex
# 100       Zhang Hang  UCVQdENY_YMQJ5Wuy2AOhGCw             zhang hang
# 101  Bigbang (Korea)  UCn5Fol5NEcyotSwqrxsedtA  Bigbear Korea channel
#
#                                         yt Description  \
# 0              xikers(싸이커스) Official YouTube Channel\n
# 1    Welcome to my channel! \nMy name is Marco, I'm...
# 2              xikers(싸이커스) Official YouTube Channel\n
# 3    The Rose Official 🌹\n\nKorean Alt Pop Band\nDU...
# 4           #ENHYPEN Official Youtube\n#ENHYPEN 공식 유튜브
# ..                                                 ...
# 97   👥SWEDISH IDENTICAL TWINS👥 - 💪BODYBUILDERS💪 - 🏆...
# 98   Votre dose de bonne humeur quotidienne !\nCo-p...
# 99   This channel is all about gaming and real life...
# 100
# 101  ทางช่องเป็นเพียงสื่อกลางในการนำเสนอแนวทางตัวเล...
#
#                  yt Published At yt View Count yt Subscriber Count  \
# 0    2022-11-15T14:21:56.347452Z      37578254              375000
# 1           2012-07-18T21:07:58Z      28337056              110000
# 2    2022-11-15T14:21:56.347452Z      37578254              375000
# 3           2016-12-16T07:48:04Z     278125618             1590000
# 4    2020-08-10T12:46:00.218737Z    1786185504             9360000
# ..                           ...           ...                 ...
# 97          2014-05-22T15:07:47Z       1660181                1970
# 98   2020-01-03T13:01:22.457303Z      50968880              919000
# 99   2023-10-24T21:18:48.892325Z         38282                 272
# 100         2018-02-27T08:24:39Z          6458                  17
# 101         2016-05-20T11:38:40Z       6403033              269000
#
#     yt Video Count
# 0              846
# 1              554
# 2              846
# 3              210
# 4             1206
# ..             ...
# 97             359
# 98              69
# 99             123
# 100             33
# 101            333
#
# [102 rows x 8 columns]

# %%
# Merge data
merged_yt = pd.merge(data, yt_channel_info_df, how='left', left_on='Headliner', right_on='yt name')

# %% [markdown]
# ## Step 4: Pull and Merge Spotify Data

# %%
def get_artist_basic_info_by_name(artist_names, sp):
    basic_spotify_records = {
        'sp artist_name': [],
        'sp artist_genre': [],
        'sp followers': [],
        'sp popularity': []
    }

    for artist_name in artist_names:
        result = sp.search(artist_name, type='artist')  # Search for the artist
        if result:
            artist = result['artists']['items'][0]
            artist_id = artist['id']
            
            artist_info = sp.artist(artist_id)

            basic_spotify_records['sp artist_name'].append(artist_name)
            basic_spotify_records['sp artist_genre'].append(artist['genres'])
            basic_spotify_records['sp followers'].append(artist_info['followers']['total'])
            basic_spotify_records['sp popularity'].append(artist['popularity'])
        else:
            print(f"No artist found for {artist_name}")

    df_basic_spotify_records = pd.DataFrame(basic_spotify_records)
    return df_basic_spotify_records

# %%
basic_spotify_records_df=get_artist_basic_info_by_name(artist_names, sp)
print(basic_spotify_records_df)
# Out:
#              sp artist_name  \
# 0                    xikers
# 1                  EVERGLOW
# 2                    Xikers
# 3                  The Rose
# 4                   ENHYPEN
# ..                      ...
# 131         Chang Cheng-Yue
# 132  Chang Cheng-Yue, Free9
# 133               Box-O-Car
# 134                  Danzig
# 135                 Anthrax
#
#                                        sp artist_genre  sp followers  \
# 0                                    [k-pop boy group]        332220
# 1                            [k-pop, k-pop girl group]       2098681
# 2                                    [k-pop boy group]        332220
# 3                             [k-pop, k-pop boy group]       2605594
# 4                             [anime, k-pop boy group]       8062354
# ..                                                 ...           ...
# 131                                                 []         51741
# 132                                                 []         51741
# 133                                                 []           339
# 134  [alternative metal, groove metal, grunge, hard...        901443
# 135  [alternative metal, glam metal, groove metal, ...       1614164
#
#      sp popularity
# 0               50
# 1               59
# 2               50
# 3               64
# 4               78
# ..             ...
# 131             61
# 132             61
# 133             19
# 134             57
# 135             55
#
# [136 rows x 4 columns]

# %%
# merge data
merged_yt_sp = pd.merge(merged_yt, basic_spotify_records_df, how='left', left_on='Headliner', right_on='sp artist_name')

# %%
## Step 5: Save Data

# %%
# Create a Pandas Excel writer
with pd.ExcelWriter(f'Merged_data.xlsx', engine='xlsxwriter') as writer:
    # Write each DataFrame to a different sheet in the Excel file
    merged_yt_sp.to_excel(writer, sheet_name=f'merged_yt_sp', index=False)
